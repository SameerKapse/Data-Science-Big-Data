# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0      52    1   0       125   212    0        1      168      0      1.0  \
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#BoxPlot
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['age'])
plt.xlabel('age')
plt.title('Boxplot of Age')
plt.show()

# %%
#Histogram
plt.figure(figsize=(8, 6))
sns.histplot(df['fbs'])
plt.xlabel('age')
plt.ylabel('Frequency')
plt.title('Histogram of age')
plt.show()

# %%
#Single Line Graph
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['age'], marker='o')
plt.xlabel('Index')
plt.ylabel('age')
plt.title('age over time')
plt.show()

# %%
df1=df[['slope']]
df1
# Out:
#       slope
# 0         2
# 1         0
# 2         0
# 3         2
# 4         1
# ...     ...
# 1020      2
# 1021      1
# 1022      1
# 1023      2
# 1024      1
#
# [1025 rows x 1 columns]

# %%
#MultiLine Graph
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['age'], marker='o', label='age')
plt.plot(df1.index, df1['slope'], marker='o', label='slope')
plt.xlabel('Index')
plt.ylabel('Metrics')
plt.title('Multiple Metrics over time')
plt.legend()
plt.show()

# %%
#Scatter Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='age', y='trestbps', hue='slope')
plt.xlabel('age')
plt.ylabel('trestbps')
plt.title('Scatter Plot of trestbpsh vs. age')
plt.show()

# %%
#Bar Graph
plt.figure(figsize=(8, 6))
sns.barplot(data=df, x='age', y='trestbps', hue='slope')
plt.xlabel('age')
plt.ylabel('trestbps')
plt.title('Bar Graph of trestbps and age')
plt.show()

# %%
#Box Plot with Notch
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='slope', y='age', notch=True)
plt.xlabel('slope')
plt.ylabel('age')
plt.title('Box Plot with Notch of age by slope')
plt.show()

# %%
#Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr())
plt.title('Correlation Heatmap of Heat Metrics')
plt.show()

# %%
#pie Chart
plt.figure(figsize=(8, 8))
category_counts = df['slope'].value_counts()
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of slope')
plt.axis('equal')
plt.show()
